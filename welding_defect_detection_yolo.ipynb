# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 27.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !scp "/content/drive/MyDrive/Welding Defect Detection/The Welding Defect Dataset - v6.zip" "/content/dataset.zip"
# !unzip "/content/dataset.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/train/images/7215c600-f4553fc8-c3_jpg.rf.e5b14eb65351196534e83013fd854ee9.jpg
#  extracting: /content/train/images/90ba92f8-fd03ae25-cracked-sun-trike-frame_jpg.rf.0bdfb09de1ca94532891ffc03e2f94a0.jpg
#  extracting: /content/train/images/90ba92f8-fd03ae25-cracked-sun-trike-frame_jpg.rf.2b3d129adee9dc87e621d28ece443249.jpg
#  extracting: /content/train/images/90ba92f8-fd03ae25-cracked-sun-trike-frame_jpg.rf.34fc1f3ca0006ee9c85e6c10aaeef9a5.jpg
#  extracting: /content/train/images/90ba92f8-fd03ae25-cracked-sun-trike-frame_jpg.rf.47b9334626a41ef85b541ae22ad19f30.jpg
#  extracting: /content/train/images/90ba92f8-fd03ae25-cracked-sun-trike-frame_jpg.rf.51240916003d66aac99d7fe08ca400ff.jpg
#  extracting: /content/train/images/90ba92f8-fd03ae25-cracked-sun-trike-frame_jpg.rf.6c9e934af6fa069e41da4cd68212998a.jpg
# ...

# %%
DATA_PATH = "data.yaml"

# %%
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# model = YOLO("yolo11n.pt")
# result_grid = model.tune(data=DATA_PATH, epochs=10, iterations=30, optimizer="AdamW", batch=32)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 134MB/s]
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/30 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 1/30 iterations complete ✅ (587.19s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.11883 observed at iteration 1
# ...

# %%
# model.train(data=DATA_PATH,
#             lr0= 0.01272,
#             lrf= 0.01057,
#             momentum= 0.94418,
#             weight_decay= 0.00055,
#             warmup_epochs= 3.10739,
#             warmup_momentum= 0.82155,
#             box= 6.48695,
#             cls= 0.50505,
#             dfl= 1.42768,
#             hsv_h= 0.01521,
#             hsv_s= 0.82539,
#             hsv_v= 0.47214,
#             translate= 0.7366,
#             scale= 0.60466,
#             epochs=50,
#             batch=16,
#             imgsz=640,
#             patience=10,
#             optimizer="SGD"
#             )
# Out:
# Ultralytics 8.3.56 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("yolo11n.pt")
model.train(data=DATA_PATH,
            epochs=100,
            batch=32,
            imgsz=640,
            patience=10
            )
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 151MB/s]
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# model = YOLO("/content/drive/MyDrive/Welding Defect Detection/output/runs/detect/train2/weights/best.pt")

# %%
result = model.val(data=DATA_PATH) #Validation with val dataset
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/valid/labels.cache... 168 images, 0 backgrounds, 0 corrupt: 100%|██████████| 168/168 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 17, len(boxes) = 416. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
#                    all        168        416      0.679      0.558      0.574      0.316
#                 Defect         88        173      0.611      0.405      0.408      0.175
#             Non-Defect        118        243      0.747      0.712       0.74      0.457
# ...

# %%
results = model.val(data="test.yaml") #Evaluate with test dataset
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/test/labels... 66 images, 0 backgrounds, 0 corrupt: 100%|██████████| 66/66 [00:00<00:00, 1685.15it/s]
# val: New cache created: /content/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:02<00:00,  1.45it/s]
#                    all         66        142      0.575      0.553      0.523      0.287
#                 Defect         31         66      0.501      0.424      0.377      0.174
#             Non-Defect         51         76      0.649      0.681      0.668        0.4
# Speed: 0.3ms preprocess, 11.5ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/train3

# %%
import locale #somehow the shell command is not working
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !cp -r "/content/runs" "/content/drive/MyDrive/Welding Defect Detection/outputdataset6b32"

# %%
# from google.colab import files

# files.download("/content/drive/MyDrive/Welding Defect Detection/output/runs/detect/train/weights/best.pt")
