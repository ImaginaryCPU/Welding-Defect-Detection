# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 27.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !scp "/content/drive/MyDrive/Welding Defect Detection/The Welding Defect Dataset - v4.zip" "/content/dataset.zip"
# !unzip "/content/dataset.zip" -d "/content"
# Out:
# Archive:  /content/dataset.zip
#   inflating: /content/README.dataset.txt
#   inflating: /content/README.roboflow.txt
#   inflating: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/02fd0af7-51ab46bb-c13_jpg.rf.101fb13b3d2f65b63262e9657e5a561f.jpg
#  extracting: /content/test/images/1aa4b44c-d01b8a11-Hot-crack_jpg.rf.edd56eb952657bdfae1ed05c530a815a.jpg
#  extracting: /content/test/images/295992d6-f617b725-c1_png_jpg.rf.d23511cf6aed5e9c4c4aa7f02bb68e00.jpg
#  extracting: /content/test/images/4a05306b-ca866e1f-c12_jpg.rf.82cf9f584d7d4231c58ff972bf59490e.jpg
#  extracting: /content/test/images/Good-Welding-images_12_jpeg_jpg.rf.5fd2ab9afe19305281d83705e8263fad.jpg
#  extracting: /content/test/images/Good-Welding-images_17_jpeg_jpg.rf.125e373108a0cbea5eb811ca26eb7365.jpg
#  extracting: /content/test/images/Good-Welding-images_23_jpeg_jpg.rf.47281acd5081684d2ca5596f5b257078.jpg
# ...

# %%
DATA_PATH = "data.yaml"

# %%
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")
model.train(data=DATA_PATH, epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/Welding Defect Detection/output/runs/detect/train2/weights/best.pt")

# %%
results = model.val()
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/valid/labels.cache... 168 images, 0 backgrounds, 0 corrupt: 100%|██████████| 168/168 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.27it/s]
#                    all        168        446      0.634      0.526      0.572       0.31
#                 Defect         90        193      0.586      0.353      0.407      0.166
#             Non-Defect        119        253      0.681        0.7      0.736      0.454
# Speed: 0.8ms preprocess, 8.2ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to runs/detect/val4

# %%
import locale #somehow the shell command is not working
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !cp -r "/content/runs" "/content/drive/MyDrive/Welding Defect Detection/output"

# %%
# from google.colab import files

# files.download("/content/drive/MyDrive/Welding Defect Detection/output/runs/detect/train/weights/best.pt")
